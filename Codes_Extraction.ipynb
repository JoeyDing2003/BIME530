# %%
import pandas as pd
import numpy as np

# %%
# Load the datasets
Atripla_1 = pd.read_csv("/Users/Joey/Downloads/BIME530_Assignment1/Athena/medication/Atripla_1.csv", sep='\t')
AIDS_1 = pd.read_csv("/Users/Joey/Downloads/BIME530_Assignment1/Athena/outcome/AIDS_1.csv", sep='\t')
AIDS_full_1 = pd.read_csv("/Users/Joey/Downloads/BIME530_Assignment1/Athena/outcome/Acquired_immunodeficiency_Syndrome_1.csv", sep='\t')
HIV_full_1 = pd.read_csv("/Users/Joey/Downloads/BIME530_Assignment1/Athena/diagnose/HIV_full_1.csv", sep='\t')

# %%
# function to extract codes of interest based on vacabulary standard
def extracting_codes(table, vocab):
    vocab_list = table[table['Vocab'] == vocab]['Code'].tolist()
    print(vocab_list)

# %%
# example
extracting_codes(AIDS_1, vocab = "SNOMED")
# Out:
# [439421000124102, 1343305005, 673571000000106, 103413000, 103414006, 103408004, 103412005, 103411003, 103418009, 170470004, 170492000, 170530008, 16810008, 286880007, 273454004, 273263000, 416729007, 420281004, 420787001, 420818005, 420900006, 421009000, 421047005, 421184005, 421230000, 420244003, 420321004, 420384005, 420395004, 421403008, 421415007, 420543008, 420544002, 420718004, 421792005, 421837008, 421883002, 421979003, 421983003, 420308006, 420452002, 420524008, 421023003, 421218006, 421272004, 421312009, 421394009, 421431004, 422337001, 420614009, 420764009, 420801006, 420945005, 420991002, 421508002, 421510000, 421874007, 421102007, 421454008, 421998001, 422003001, 422031005, 422241000, 422282000, 420302007, 420403001, 420549007, 420554003, 420615005, 421571007, 421597001, 421695000, 421706001, 421710003, 421766003, 421835000, 421929001, 420658009, 420687005, 420691000, 420749009, 420774007, 420877009, 420938005, 421077004, 421977001, 422012004, 422074008, 422127002, 422159
# ...
